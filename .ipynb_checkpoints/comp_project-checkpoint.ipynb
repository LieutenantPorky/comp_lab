# %% [markdown]
# # Computational methods in Physics

# %% [markdown]
# # Introduction
#
# The use of computation in mathematics and physics has brought a revolution in our ability to understand, test and generally "play around" with new concepts. Being able to quicky create simulations of phenomena which would otherwise be very difficult to consider analytically has allowed theories to be quickly tested and, more importantly, has provided a tool to build intuition for a problem, by being able to change parameters and make observations easily. Computers allow students to play around with concepts that are traditionally quite hard for them to understand intuitively, such as special relativity, providing a way to test different ideas and interpretations they might have until the concept becomes more natural.
#
# The use of high-level interpreted languages like Python or Mathematica has rendered this process even easier, by abstracting away unnecessary complications like data types or static arrays that are common in low-level languages, therefore allowing programmers to focus more clearly on algorithms in exchange for a usually acceptable loss in computational efficiency. Python, with its open source nature and community, has proven to be an especially good environment for scientific computing due both to the relative simplicity of the language and the widespread availability and support of many packages.
#
# This notebook considers two separate problems that can be addressed computationally. In the first part, the long-term stability of a specific finite-difference model of population growth is investigated, by observing the structure of fixed points as the model converges for various initial conditions and growth coefficients. The distribution of the fixed points is graphed, and a way of measuring the isotropy is provided to quantify certain aspects.
#
# Secondly, a basic montecarlo algorithm is developed and applied to both one-dimensonal and two-dimensional integration problems. The relative error of the algorithm is measured against the nummber of samples, and the result is plotted to establish a relationship. Which is found to be preserved regardless of the dimensionality of the problem.

# %%
import numpy as np
import matplotlib
matplotlib.rc('text', usetex = True)

import matplotlib.pyplot as plt

# %% [markdown]
# # Part 1 - modelling poulation growth
#
# ### Theory
# Population dynamics are a dynamical system, whose change depends on the current size of the population as well as certain constants describing the system. A simple iterative model can be constructed by considering the growth of the next generation as being directly proportional to the current population number by some scalar multiple, indicating the relative population growth (the ratio of births to deaths given infinite resources). However, it is fairly evident that such a population would continue growing exponentially. Real-world systems have an additional constraint imposed by finite resource availability, which slows down population growth as the population size approaches a limit (the carrying capacity). One can describe the next iteration of this population model as
#
# $$ x_{n+1} = a \times x_{n} \times (1 - x_{n}) $$
#
# where $x_{n}$ and $x_{n + 1}$ are, respectively, the size of the current and next generation as a fraction of the carrying capacity, and $a$ is the ratio of the birth and death rate under limitless resources.
#
# One would expect that such a model would eventually reach an equilibrium, dictated by the carrying capacity - indeed, this is the case if one cosiders the changes to be derivatives, and treats the model as a differential equation. However, for finite-difference models, this does not always occur, and the population may instead continuously oscillate or behave chaotically after certain critical values of the expansion coefficient $a$.
#
# ### Implementation
# To facilitate future modification, the algorithm has been designed with modularity in mind. The long-term equilibrium of a given population is calculated by `getConvergence()`, a functional returning the result of the repeated application of some input function (executed through a for loop) to an initial value to determine convergence. The input function can be separately defined, to allow easy modification of test models, but is in this case crated by `getPopFunction()`, which returns the stated population function for a given value of $a$. `getConvergence()` is used inside `randomCurve()` to generate a theoretical convergence value for a random initial condition and a given value of $a$. It should be noted that the function need not converge, in which case the final value will be pseudorandom, determined chaotically by the initial value and the iteration number. This process is repeated through another for loop to obtain 50 datapoints at a certain value of $a$, which is swept over the required range. The resultant convergence values are then stored in `aSweep`, a matrix of ($a$ value, convergence) pairs:
#
# $$
# \mathrm{aSweep} =
# \begin{bmatrix}
# [a_{0}, \mathrm{conv.}_{0}] & [a_{0}, \mathrm{conv.}_{1}] & [a_{0}, \mathrm{conv.}_{2}]  & \dots\\
# [a_{1}, \mathrm{conv.}_{0}] & [a_{1}, \mathrm{conv.}_{1}] & [a_{1}, \mathrm{conv.}_{2}]  & \dots\\
# [a_{2}, \mathrm{conv.}_{0}] & [a_{2}, \mathrm{conv.}_{1}] & [a_{2}, \mathrm{conv.}_{2}]  & \dots\\
# \vdots & \vdots & \vdots & \ddots \\
# \end{bmatrix}
# $$
#
# These values are then unpacked into two vectors of index-wise $a$ and convergence values, and plotted as single points using matplotlib.

# %%
#This function returns the population growth function for a given "a" value
def getPopFunction(a):
    return lambda n : a * n * (1 - n)

#Determine the convergence of a certain population function after an arbitrary number of iterations:

def getConvergence(initial, popFunction, iterations):
    for i in range(0,iterations):
        initial = popFunction(initial)
    return initial

#Initialize a population with a random size, and iterate with a = 1 to find the convergence (with 100 iterations)

def randomCurve(a, iterations):
    return [a, getConvergence(np.random.random(),getPopFunction(a), iterations)]

# %%
#now, iterate that function through 2000 values of a in [1.5,4]
aSweep = [[randomCurve(a,100) for i in range(0,50)] for a in np.linspace(1.5,4,2000)]

#unpack and plot the obtained values, reducing the point size to 0.1 to resolve detail
ax = plt.subplot(111)
plt.xlabel(r"$a$")
plt.ylabel("Population size")
ax.plot([[j[0] for j in i] for i in aSweep], [[j[1] for j in i] for i in aSweep],'bo', ms=0.1)
plt.show()

# %%
#Same as above, but for a in [3,4] and [3.5,3.8]
aSweep2 = [[randomCurve(a,100) for i in range(0,50)] for a in np.linspace(3,4,2000)]

ax1 = plt.subplot(211)
ax1.set_ylim(0,1)
ax1.plot([[j[0] for j in i] for i in aSweep2], [[j[1] for j in i] for i in aSweep2],'bo', ms=0.1)

aSweep2 = [[randomCurve(a,100) for i in range(0,50)] for a in np.linspace(3.5,3.8,2000)]

ax2 = plt.subplot(212)
ax2.set_ylim(0.25,0.5)
ax2.plot([[j[0] for j in i] for i in aSweep2], [[j[1] for j in i] for i in aSweep2],'bo', ms=0.1)

plt.show()

# %% [markdown]
# ### Quantifying fixed point spread
#
# A more objective consideration of chaotic phenomena in the model can be obtained by quantifying the variance in the density of obtained convergence values. For lower values of $a$, and therefore a non-chaotic system, one expects all the fixed points to be concentrated around a specific value. Conversely, the spread should tend towards isotropy for larger values of $a$.
#
# To obtain this information, the data was divided into discrete regions, each with covering a certain group of $a$ and convergence values. A numerical point density was computed for each region, by iterating through the data obtained from the model and counting points within the region boundary (counted points were then removed from the data array for computational efficiency, preventing future loops from having to count those same points). The density was stored in a matrix, where each element corresponded to a cell, with each row having the same value for $a$ but increasing in value for convergence. Finally, the standard deviation of each row of group densities was computed and plotted versus their $a$ value. Rows where the function converges to a single point would be expected to have a very high standard deviation, as the data is very unequal. Conversely, chaotic regions demonstrate isotropic distributions, and one would therefore expect a lower standard deviation for these regions.
#
# From the obtained graph, two large drops in standard deviation are observed: one at $a$ = 2.9, corresponding to the start of the oscillatory region, and one at $a$ = 3.5, indicating the chaotic region. Furthermore, near $a$ = 3.8, a spike in standard deviation indicates the region of stability observed in the population graph.

# %%
'''
Note - for some reason, this section didn't reliably work on the uni computers - it might be a problem with
not having enough memory, or something to do with python 2 (since the notebook was written with python 3)
'''


#We need to divide the area into regions and calculate an average numerical density
aSize = 100
cSize = 10

aWidth = (4 - 1.5) / aSize
cWidth = 1 / cSize

aSweep = [[randomCurve(a,100) for i in range(0,50)] for a in np.linspace(1.5,4,500)]

densityMatrix = [[0 for i in range(0,cSize)] for j in range(0,aSize)]
aVector = [] # transform values from a matrix to a vector
for i in aSweep:
    aVector = aVector + i

#for each cell, figure out how many  (a, convergence) pairs are enclosed

for aIndex, aValue in enumerate(np.linspace(1.5,4,aSize, endpoint=False)):
    for cIndex, cValue in enumerate(np.linspace(0,1,cSize, endpoint = False)):
        regionNum = 0        
        # check all [a, conv] pairs, and add them to the region counter if inside region
        
        for index, pair in enumerate(aVector):
            if (aValue + aWidth > pair[0] and aValue < pair[0]) and (cValue + cWidth > pair[1] and cValue < pair[1]): #if the point is inside the region
                regionNum += 1
                del aVector[index] # delete points we added, to increase efficiency on future loops
        densityMatrix[aIndex][cIndex] = regionNum # update the corresponding density

plt.xlabel(r"$a$")
plt.ylabel("standard deviation in density")
plt.plot(np.linspace(1.5,4,aSize, endpoint=False), [np.std(i) for i in densityMatrix]) #plot the standard deviation of columns
plt.show()

# %% [markdown]
# ### Convergence and chaotic phenomena
#
# As can be seen from the produced graphs, the population dynamics are fairly predicatable for low values of $a$, with any initial value converging to a single fixed point. However, this convergence does not occur when the growth constant $a$ surpasses a certain constant, with the long term behaviour of the population being a regular oscillatory system for intermediate values or chaotic for larger values.
#
# For growth constants in the range of 2.9 - 3.5, the single fixed point convergence degenerates into an oscillatory condition. The population globally converges to a pattern that oscillates regularly between $2^n$ values (indipendent of initial conditions), with $n$ being an integer increasing with $a$. The branching patterns appear as fractals, as each branch point is self-similar to the parent node. While the number of nodes is infinite, the length of each section decreases dramatically, with the ratio of the parent to child length approaching the first Feigenbaum constant ($\delta \approx$ 4.67) with each iteration of the fractal.
#
# Beyond $a$ = 3.5, the sequence becomes chaotic. The evolution of a single population is very strongly dependent on initial conditions and diverges broadly from other populations with similar conditions. While there is an attractive region dependent on $a$, the size of this area rapidly increases, leading to further population scattering. There are, however, certain intervals where smaller attractor regions appear, leading to a renewed oscillatory behaviour for certain values of $a$ (eg. $a \approx$ 3.83). The chaotic interval also exhibits a type of self-similarity, as the isotropic spread of points is visible at both small and large scales (similar to brownian motion, in which short-term dispersion is self-similar to long-term dispersion - a plot of brownian motion looks the same at any magnification).
#
# Interestingly, this effect is not observed if we consider a modification of the model based on differential changes, and then attempt to find a stable numerical solution to the obtained differential equation (using scipy's 4th-order RK solver), and the chaotic effects observed require a finite-difference model.

# %%
#Plot specific populations at different values of a: some will converge, some will oscillate regularly,
#and some are chaotic

#Apply the population growth function every step, but this time save the population number every time, not just at the end

def getEvolution(initial, function, iterations):
    datapoints = [[0, initial]]
    for i in range(1,iterations):
        datapoints.append([i, function(datapoints[i-1][1])])
    return datapoints

ax0 = plt.subplot(411)
ax1 = plt.subplot(412)
ax2 = plt.subplot(413)
ax3 = plt.subplot(414)

#Plot populations for a= 3.8(chaotic), 3.5 (oscillatory on 4 points), 3.2 (oscillatory on 2 points) and 2.5 (converges cleanly)

path = getEvolution(0.5, getPopFunction(3.8), 100)
ax0.plot([i[0] for i in path], [i[1] for i in path])
ax0.set_title(r"$a$ = 3.8")

path = getEvolution(0.5, getPopFunction(3.5), 100)
ax1.plot([i[0] for i in path], [i[1] for i in path])
ax1.set_title(r"$a$ = 3.5")

path = getEvolution(0.5, getPopFunction(3.2), 100)
ax2.plot([i[0] for i in path], [i[1] for i in path])
ax2.set_title(r"$a$ = 3.2")

path = getEvolution(0.5, getPopFunction(2.5), 100)
ax3.plot([i[0] for i in path], [i[1] for i in path])
ax3.set_title(r"$a$ = 2.5")

plt.tight_layout()
plt.show()

# %%
import scipy.integrate

#Example of how oscillatory behaviour only occurs in finite-difference integration - A model based on infinitesimal
#growth does not demonstrate long-term oscillatory patterns, and instead will converge.

diffSolution = scipy.integrate.solve_ivp(lambda t,y : 3.2 * y * (1 - y), [0,10], [0.5], t_eval = np.linspace(0,10,50))

plt.plot(diffSolution.t, diffSolution.y[0])
plt.show()

# %% [markdown]
# # Part 2 - montecarlo integration
#
# Montecarlo algorithms are a non-deterministic approach to solving certain computational problems. Instead of directly calculating an exact solution, which may be impractical or computationally expensive, the Montecarlo approach consists of attempting to "guess" the solution by sampling the problem space at different points, and then iteratively improving the initial guess by taking more samples. Given a large enough sample size, the estimate should converge to the true answer, with the error rate diminishing as $\frac{1}{\sqrt{n}}$ given n samples, regardless of the type of problem.

# %% [markdown]
# ### 1D integration
#
# To integrate single-valued functions through montecarlo, a region encompassing the bounds of integration has to first be created, from which samples will be taken. The horizontal bounds of the region are simply the upper and lower bounds of integration that are given, but the vertical bounds must either be assigned arbitrarily or taken to be the global maximum and minimum of the function $f$ on the given region. These two values can be approximated by evaluating the function at several points, and choosing the highest and lowest values.
#
# Once the bounding box has been determined, samples can be obtained by creating a tuple of two random numbers enclosed within the bounds, representing a single point $(x,y)$. For each point, the $y$ value can be compared to the value of $f(x)$. If $f(x) \times y > 0$ (that is, if the two values have the same sign), and $|f(x)| > |y|$, then the point lies within the area bounded by the integrand. A counter is used to keep track of points within the region, with valid points above the x-axis incrementing the counter by one, and points below decreasing it by one (to account for the "negative area" of negative-valued integrands). Finally, the value of the integral is computed by taking the value of the counter, dividing it by total number of points to obtain a ratio of points within the integral to total points, and finally multiplying this ratio by the total area of the bounding box.

# %%
def montecarloIntegrate(function, bounds, plot=False, iterations = 10000):
    #First thing we need to do is find the bounding box of the function - we know that sin^4 is bounded by [0,1], but
    #arbitrarily choosing these values is not very generalizable (also it's cheating -_-)
    
    testSeq = [function(i) for i in np.linspace(bounds[0], bounds[1], 200)]
    if plot : plt.plot(np.linspace(bounds[0], bounds[1], 200), testSeq)
    
    #find the global maxima and minima of the function
    gMax = np.amax(testSeq)
    gMin = np.amin(testSeq)
    diff = gMax - gMin

    # now we have the vertical bounds - we just need to create a bunch of random points in the area and check whether
    #they are smaller than the function
    numInside = 0.0
    
    
    for x,y in zip(np.random.random(iterations) * (bounds[1] - bounds[0]) + bounds[0], np.random.random(iterations) * diff + gMin):
        value = function(x)            
        #Firstly, the point must have the same sign as the function to be under the curve:
        if (value * y >= 0):
            # if it has the same sign, check whether it is under the curve
            if (np.abs(value) > np.abs(y)):
                #Now, if the value is negative, subtract a point from the total. Else, add a point
                if value < 0:
                    if plot : plt.plot(x,y,'bo')
                    numInside -= 1
                else:
                    numInside += 1
                    if plot : plt.plot(x,y,'ro')
            else:
                if plot : plt.plot(x,y,'ko')
        else:
            if plot : plt.plot(x,y,'ko')
    
    # Now, find ratio of points inside and outside the bounds, and multiply by total area:
    
    return numInside / iterations * diff * (bounds[1] - bounds[0])

# %%
# first compute with few iterations, to plot the points
montecarloIntegrate(lambda x : np.sin(x) ** 4, [0.0, 0.5 * np.pi], iterations = 200, plot = True)

# now use many more samples, but don't plot to do this quickly
print(montecarloIntegrate(lambda x : np.sin(x) ** 4, [0.0, 0.5 * np.pi]))
plt.show()
# Out:
# 0.5992587986722531

# %%
# as a showcase, here's a function with negative values as well
montecarloIntegrate(lambda x : np.sin(x), [0.0, 2 * np.pi], iterations = 200, plot = True)
print(montecarloIntegrate(lambda x : np.sin(x), [0.0, 2 * np.pi]))
plt.show()
# Out:
# 0.025131958265770703

# %% [markdown]
# ### Manually computing the integral
#
# We consider the integral
# $$\int \sin^{4}x \mathop{}\!\mathrm{d}x$$
#
# The sine can be split, and then integration by parts can be applied
#
# $$\int \sin^{4}x \mathop{}\!\mathrm{d}x = \int \sin^{3}x \sin x \mathop{}\!\mathrm{d}x = -\sin^{3}x \cos x + \int 3\sin^{2}x \cos^{2} x \mathop{}\!\mathrm{d}x $$
#
# Noting that $ 2\sin x \cos x = \sin 2x$,
#
# $$ -\sin^{3}x \cos x + \int \frac{3}{4}\sin^{2}2x \mathop{}\!\mathrm{d}x$$
#
# $\cos 2x = \cos^{2} x - \sin^{2} x = 1 - 2\sin^{2}x$, allowing us to express $\sin^{2}$ in terms of $\cos 2x$. This then allows us to finally compute the integral.
#
# $$-\sin^{3}x \cos x + \int \frac{3}{8}(1 - \cos 4x) \mathop{}\!\mathrm{d}x =
# -\sin^{3}x \cos x + \frac{3}{8}(x - \frac{\sin 4x}{4}) + C$$
#
# Collecting the terms,
#
# $$-\sin^{3}x \cos x + \frac{3}{8}x - \frac{3\sin 4x}{32} + C$$
#
# We can simplify this expression:
#
# $$ \sin^{3}x \cos x = \sin^{2} x \sin x \cos x = \frac{1}{2}(1 - \cos 2x)\frac{1}{2}(\sin 2x) = \frac{1}{4}\sin 2x - \frac{1}{8} \sin 4x$$
#
# Plugging back into our original expression,
#
# $$-(\frac{1}{4}\sin 2x - \frac{1}{8} \sin 4x) + \frac{3}{8}x - \frac{3\sin 4x}{32} =
# \frac{3}{8}x - \frac{1}{4}\sin 2x + \frac{1}{32}\sin 4x$$
#
# Therefore,
#
# $$ \int \sin^{4}x \mathop{}\!\mathrm{d}x = \frac{3}{8}x - \frac{1}{4}\sin 2x + \frac{1}{32}\sin 4x + C $$
#
# For the specific example, we are considering the definite integral
#
# $$\int^{\pi / 2}_{0} \sin^{4}x \mathop{}\!\mathrm{d}x$$
#
# which can be computed through the above indefinite integral to be $\frac{3\pi}{16} \approx 0.589$

# %% [markdown]
# ### Error
#
# One of the large advantages of montecarlo methods versus other numerical algorithms is the fact that their error scales as $\frac{1}{\sqrt{n}}$, regardless of dimensionality or complexity of the problem. This can be seen by plotting the relative error of the montecarlo algorithm versus the integral computed by hand, and plotting it against the number of samples on a log plot. Linear regression of the plot shows a slope of approximately -0.5, corresponding to the the inverse root relation that is expected.

# %%
# plot the error as a function of sample size (in a log plot)

samples = [10 ** n for n in np.linspace(1,4,20)] # number of samples

logS = np.log([int(i) for i in samples]) # take the log of those samples
#evauate the relative error, adding a small extra amount to avoid getting log(0) 
logD =  np.log((0.00001 + np.abs(np.array([montecarloIntegrate(lambda x : np.sin(x) ** 4, [0.0, 0.5 * np.pi], iterations = int(i)) for i in samples]) - 3 * np.pi / 16.0) / (3 * np.pi / 16.0)))

fit = np.polyfit(logS, logD, 1) # linreg to find best fit
print("Slope is: {}".format(np.round(fit[0],1)))
plt.plot(logS,logD)
plt.plot(np.linspace(logS[0], logS[-1],100), [np.poly1d(fit)(i) for i in np.linspace(logS[0], logS[-1],100)], "g--") # plot the best fit


plt.xlabel(r"log of samples")
plt.ylabel(r"log of relative error")
plt.show()
# Out:
# Slope is: -0.5

# %% [markdown]
# ### Montecarlo in 3D
#
# Computing volumes with a montecarlo algorithm is very similar ot computing integrals, except the two-tuple of random points becomes an n-tuple. For every sample, a counter is incremented if the square of the distance to the origin (computed by summing the squares of the random coordinates) is between the squared radius of the two spheres. The final volume is computed by multiplying the ratio of points within the region and the volume of the bounding box.
#
# The true volume is easy to compute analytically: the volume of a sphere is
# $$ \frac{4}{3} \pi R^{3}$$
# and therefore the volume of the region is
# $$\frac{4}{3}\pi (R_{1}^{3} -R_{2}^{3}) \approx 2.422$$

# %%
#For 3 dimensions, the integration path/volume/surface is a function
def isShell(point):
    r1 = 0.75
    r2 = 1
    return sum([i ** 2 for i in point]) >= r1 ** 2 and sum([i ** 2 for i in point]) <= r2 ** 2

def integrateVolume(volume, samples):
    total = 0.0
    for i in range(0,samples):
        #create a random point in 3d space, with coordinates in [0,1]
        point = [2 * i - 1 for i in np.random.random(3)]
        if volume(point):
            total += 1
    return total / samples * 2**3

print (integrateVolume(isShell, 10000))
# Out:
# 2.4816

# %%
# plot the error as a function of sample size (in a log plot)

samples = [10 ** n for n in np.linspace(1,4,20)] # number of samples

logS = np.log([int(i) for i in samples]) # take the log of those samples
#evauate the relative error, adding a small extra amount to avoid getting log(0) 
logD =  np.log((0.00001 + np.abs(np.array([integrateVolume(isShell, int(i)) for i in samples]) - (4.0/3*np.pi*(1-0.75**3))) / (4.0/3*np.pi*(1-0.75**3))))

fit = np.polyfit(logS, logD, 1) # linreg to find best fit
print("Slope is: {}".format(np.round(fit[0],1)))
plt.plot(logS,logD)
plt.plot(np.linspace(logS[0], logS[-1],100), [np.poly1d(fit)(i) for i in np.linspace(logS[0], logS[-1],100)], "g--") # plot the best fit


plt.xlabel(r"log of samples")
plt.ylabel(r"log of relative error")
plt.show()
# Out:
# Slope is: -0.5

# %% [markdown]
# Again, plotting the relative error versus on a log plot shows that the inverse-root relation holds even in three dimensions, as is expected with a montecarlo algorithm. By using random sampling, the algorithm is attempting to compute the expected value of a certain problem, rather than utilising the dynamics of the problem itself to obtain a numerical answer. This effectively transforms an n-dimensional problem into a one-dimensional expected value problem, with variance proportional to the inverse root of the number of samples.
#
# ### Comparison with other methods
#
# For lower dimensional problems, simple montecarlo integration does not really have major advantages over other numerical methods, such as Riemman or trapezoid integration. While it may be better at dealing with very irregular functions, it would have trouble with very sharp ones. While more advanced sampling techniques (eg. importance sampling) would allow to mitigate this problem, such algorithms are more complicated to implement than optimizations in other integration methods. The advantage of montecarlo algorithms, however, shows with higher dimensional problems. While the algorithm for calculating the volume of the spherical shell using a regular grid of points would not be excessively complicated, to improve the accuracy of the results requires adding enough sample points to fill a higher resolution grid. With the montecarlo method, samples can be added linearly, allowing for faster computation given a required level of precision. In addition, modifications to the basic montecarlo algorithm can be made to allow a different, non-isotropic distribution of samples. This technique, called importance sampling, allows to focus computational power onto more variable regions of the problem rather than distributing it equally, and allows for more precision to be achieved with the same number of samples.

# %% [markdown]
# # Conclusion
#
# The use of computation in physics has allowed to play around with and test new ideas in ways that were unimaginable just a few decades ago. The ability to quickly create simulations and experiment with physics before deciding to "commit" to a theory and work through a more rigorous mathematical framework not only is a great asset when creating new theories, but is very helpful for students, who are given the power to "mess around" with maths and physics to figure out how a process might work. I think the single most important thing a computational class should do is encourage students to play around and have fun with code, and allow them to understand just how powerful a computer can be in helping them understand the world.
#
# In terms of the problems that were approached in this notebook, the finite-difference model of population growth shows how rapidly-growing populations can become unstable and evolve chaotically, or oscillate in a stable pattern between different values. It's especially interesting how both predictable behaviour, fractal self-similarity and chaos can emerge from a single, simple relation, and there is definitely a lot more that can be investigated from the first problem. It would be particularly interesting to study how the initial conditions affect the time evolution of each separate "population line", especially in the range of $a$ that gives rise to oscillatory phenomena. The main difficulty in this case would be to create an intuitive way to visualise the data, which would have several inputs.
#
# The montecarlo problem illustrates some of the basic uses of montecarlo algorithms, as well as the inverse-root relation between the error and the number of samples. It also shows how this relation is preserved regardless of the dimensionality of the problem. It would be interesting to implement some form of basic importance sampling in the algorithm, and potentially use it to graph an "uglier" function that would not work well with standard montecarlo or deterministic methods (maybe something like a very sharp gaussian). The algorithm could work by dividing the integrating region into different intervals, each with a different number of samples based on some calculated "relative complexity". Different methods of choosing the regions and evaluating the complexity could be investigated, to find pros and cons of each one. An extension of this method to multiple dimensions could also be derived.
